# %%
x=2

# %%
x
# Out:
# 2

# %%
y=5

# %%
y
# Out:
# 5

# %%
x+y
# Out:
# 7

# %%
z=x+y

# %%
z
# Out:
# 7

# %%
a=5

# %%
b=3

# %%
a-b
# Out:
# 2

# %%
def add(m,n):
    result=m+n
    return result

# %%
add(20,10)
# Out:
# 30

# %%
add(25,25)
# Out:
# 50

# %%
def sub(p,q):
    result=p-q
    return result

# %%
sub(20,10)
# Out:
# 10

# %%
def

# %% [markdown]
#   ## list

# %%
market=["car","shoe","furniture"]

# %%
market
# Out:
# ['car', 'shoe', 'furniture']

# %%
house=["iron","television","chair"]

# %%
house
# Out:
# ['iron', 'television', 'chair']

# %%
market.append("salt")

# %%
market
# Out:
# ['car', 'shoe', 'furniture', 'salt']

# %%
house.append("table")

# %%
house
# Out:
# ['iron', 'television', 'chair', 'table']

# %%
import pandas as luke

# %%
luke.DataFrame({"market":market,"house":house})
# Out:
#       market       house
# 0        car        iron
# 1       shoe  television
# 2  furniture       chair
# 3       salt       table

# %%
market[0]
# Out:
# 'car'

# %%
market[1]
# Out:
# 'shoe'

# %%
market[2]
# Out:
# 'furniture'

# %%
market[3]
# Out:
# 'salt'

# %%
market[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 market[4]
#
# IndexError: list index out of range

# %%
mythings_dictionary={"fruits":["apple","banana","cherry"],"colors":["red","green","blue"],"numbers":[1,2,3,4,5]}

# %%
mythings_dictionary
# Out:
# {'fruits': ['apple', 'banana', 'cherry'],
#  'colors': ['red', 'green', 'blue'],
#  'numbers': [1, 2, 3, 4, 5]}

# %%
mythings_dictionary["fruits"]
# Out:
# ['apple', 'banana', 'cherry']

# %%
mythings_dictionary["fruits"][2]
# Out:
# 'cherry'

# %%
mythings_dictionary["fruits"][1]
# Out:
# 'banana'

# %%
import requests
 
 
api_url = "http://universities.hipolabs.com/search?country=United+States"

# %%
response = requests.get(api_url)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# [{'state-province': None,
#   'web_pages': ['http://www.marywood.edu'],
#   'name': 'Marywood University',
#   'domains': ['marywood.edu'],
#   'alpha_two_code': 'US',
#   'country': 'United States'},
#  {'state-province': None,
#   'web_pages': ['http://www.lindenwood.edu/'],
#   'name': 'Lindenwood University',
#   'domains': ['lindenwood.edu'],
#   'alpha_two_code': 'US',
#   'country': 'United States'},
#  {'state-province': None,
#   'web_pages': ['https://sullivan.edu/'],
#   'name': 'Sullivan University',
#   'domains': ['sullivan.edu'],
#   'alpha_two_code': 'US',
#   'country': 'United States'},
#  {'state-province': None,
#   'web_pages': ['https://www.fscj.edu/'],
#   'name': 'Florida State College at Jacksonville',
#   'domains': ['fscj.edu'],
#   'alpha_two_code': 'US',
#   'country': 'United States'},
#  {'state-province': None,
#   'web_pages': ['https://www.xavier.edu/'],
#   'name': 'Xavier University',
#   'domains': ['xavier.edu'],
#   'alpha_two_code': 'US',
# ...

# %%
Data=response.json()

# %%
luke.DataFrame(Data)
# Out:
#      state-province                     web_pages  \
# 0              None     [http://www.marywood.edu]
# 1              None  [http://www.lindenwood.edu/]
# 2              None       [https://sullivan.edu/]
# 3              None       [https://www.fscj.edu/]
# 4              None     [https://www.xavier.edu/]
# ...             ...                           ...
# 2264           None       [https://csupueblo.edu]
# 2265           None            [https://bau.edu/]
# 2266           None      [https://www.siena.edu/]
# 2267           None          [https://txwes.edu/]
# 2268             NY       [https://www.idti.edu/]
#
#                                        name           domains alpha_two_code  \
# 0                       Marywood University    [marywood.edu]             US
# 1                     Lindenwood University  [lindenwood.edu]             US
# 2                       Sullivan University    [sullivan.edu]             US
# ...

# %%
Data.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 Data.describe()
#
# AttributeError: 'list' object has no attribute 'describe'
